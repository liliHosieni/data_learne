# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/data.csv', header=None)
data.head(5)
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
plt.plot(data[0],'go--')

# %%
figure = plt.figure()
af1 = figure.add_subplot(2,2,1)
af2 = figure.add_subplot(2,2,2)
af3 = figure.add_subplot(2,2,3)
af4 = figure.add_subplot(2,2,4)

af1.scatter(data[0], data[1])
af2.hist(data[1], color='g', bins=20, alpha= 0.3)
af3.plot(data[4])
af4.acorr(data[3])
plt.subplots_adjust(wspace=0.5, hspace=0)#فاصله بین نمودار ها
plt.savefig('didi.pdf', dpi=400, bbox_inches='tight')

# %%
fig, axes = plt.subplots(2, 3)
axes[0,0].hist(data[2], bins=20)
# Out:
# (array([ 4., 33., 11.,  2.,  0.,  0.,  1.,  2.,  3.,  5., 12., 14., 12.,
#         17.,  6., 12.,  7.,  4.,  2.,  3.]),
#  array([1.   , 1.295, 1.59 , 1.885, 2.18 , 2.475, 2.77 , 3.065, 3.36 ,
#         3.655, 3.95 , 4.245, 4.54 , 4.835, 5.13 , 5.425, 5.72 , 6.015,
#         6.31 , 6.605, 6.9  ]),
#  <BarContainer object of 20 artists>)

# %%
fig, ax = plt.subplots(1,1)
ax.plot(data[0])
ax.set_title('fucking plot:)))')
ax.set_ylabel('fucking data[0]')
ax.set_xticks([0,50,100,150])
ax.set_xticklabels(['fuck1','fuck2', 'fuck3', 'fuck4'])
#روش کوتاه تر:)
#props = {
# 'title': 'My first matplotlib plot',
# 'xlabel': 'Stages'
#}
#ax.set(**props)
# Out:
# [Text(0, 0, 'fuck1'),
#  Text(50, 0, 'fuck2'),
#  Text(100, 0, 'fuck3'),
#  Text(150, 0, 'fuck4')]

# %%
fig, axx = plt.subplots(1)
axx.plot(data[1])
axx.annotate('fuck you!', xy=[1, 3],arrowprops=dict(facecolor='black', headwidth=4, width=2,
 headlength=4))
# Out:
# Text(1, 3, 'fuck you!')

# %%
data.plot()
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2)
data[3][:10].plot.barh(ax= axes[0], color='g', alpha=0.5)
data[3][:10].plot.bar(ax= axes[1], color='g')
data[:10].plot.barh(stacked= True)
# Out:
# <Axes: >

# %%
data[1].plot.density()#نمودار چگالی
# Out:
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
sns.distplot(data[1])
# Out:
# C:\Users\hosieni.amin\AppData\Local\Temp\ipykernel_7096\2774267997.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[1])
# <Axes: xlabel='1', ylabel='Density'>

# %%
sns.pairplot(data, plot_kws={'alpha': 0.2})
